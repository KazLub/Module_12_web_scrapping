# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com/'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
html = browser.html
soup = soup(html, 'html.parser')

# %%
# Extract all the text elements
results = soup.find_all('div', class_='list_text')

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries
title_list = []
text_list=[]

# %%
# Loop through the text elements
for result in results:

# Extract the title and preview text from the elements
    titles = result.find('div', class_='content_title').text

    preview_text = result.find('div', class_='article_teaser_body').text
    
# Store each title and preview pair in a dictionary
# Add the dictionary to the list
    title_list.append(titles)
    text_list.append(preview_text)

    print('-------------')
    print('Title: ' + str(titles))
    print('Preview text: ' + str(preview_text))
    print('-------------')
# Out:
# -------------
# Title: Scientists Explore Outback as Testbed for Mars
# Preview text: Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.
# -------------
# -------------
# Title: From JPL's Mailroom to Mars and Beyond
# Preview text: Bill Allen has thrived as the mechanical systems design lead for three Mars rover missions, but he got his start as a teenager sorting letters for the NASA center.
# -------------
# -------------
# Title: The MarCO Mission Comes to an End
# Preview text: The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.
# -------------
# -------------
# Title: NASA's Mars 2020 Rover Tests Descent-Stage Separation
# Preview text: A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.
# -------------
# -------------
# Title: NASA's Mars 2020 Heads Into the Test Chamber
# Preview text: In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.
# -------------
# -------------
# Title: NASA Invites Students to Name Mars 2020 Rover
# Preview text: Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.
# -------------
# -------------
# Title: All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover
# Preview text: SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.
# -------------
# -------------
# Title: NASA's Mars 2020 Rover Closer to Getting Its Name
# Preview text: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# -------------
# -------------
# Title: Two Rovers to Roll on Mars Again: Curiosity and Mars 2020
# Preview text: They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.
# -------------
# -------------
# Title: NASA's Push to Save the Mars InSight Lander's Heat Probe
# Preview text: The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole.
# -------------
# -------------
# Title: NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb
# Preview text: Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.
# -------------
# -------------
# Title: While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus
# Preview text: This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.
# -------------
# -------------
# Title: Mars Is Getting a New Robotic Meteorologist
# Preview text: Sensors on NASA's Perseverance will help prepare for future human exploration by taking weather measurements and studying dust particles.
# -------------
# -------------
# Title: Meet the People Behind NASA's Perseverance Rover
# Preview text: These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater.
# -------------
# -------------
# Title: HiRISE Views NASA's InSight and Curiosity on Mars
# Preview text: New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.
# -------------

# %%
# Print the list to confirm success
title_list
# Out:
# ['Scientists Explore Outback as Testbed for Mars ',
#  "From JPL's Mailroom to Mars and Beyond",
#  'The MarCO Mission Comes to an End',
#  "NASA's Mars 2020 Rover Tests Descent-Stage Separation",
#  "NASA's Mars 2020 Heads Into the Test Chamber",
#  'NASA Invites Students to Name Mars 2020 Rover',
#  "All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover",
#  "NASA's Mars 2020 Rover Closer to Getting Its Name",
#  'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020',
#  "NASA's Push to Save the Mars InSight Lander's Heat Probe",
#  "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#  "While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus",
#  'Mars Is Getting a New Robotic Meteorologist',
#  "Meet the People Behind NASA's Perseverance Rover",
#  "HiRISE Views NASA's InSight and Curiosity on Mars",
#  'Scientists Explore Outback as Testbed for Mars ',
#  "From JPL's Mailroom to Mars and Beyond",
#  'The MarCO Mission Comes to an End',
#  "NASA's Mars 2020 Rover Tests Descent-Stage Separation",
#  "NASA's Mars 2020 Heads Into the Test Chamber",
#  'NASA Invites Students to Name Mars 2020 Rover',
#  "All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover",
#  "NASA's Mars 2020 Rover Closer to Getting Its Name",
#  'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020',
#  "NASA's Push to Save the Mars InSight Lander's Heat Probe",
#  "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#  "While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus",
#  'Mars Is Getting a New Robotic Meteorologist',
#  "Meet the People Behind NASA's Perseverance Rover",
#  "HiRISE Views NASA's InSight and Curiosity on Mars",
#  'Scientists Explore Outback as Testbed for Mars ',
#  "From JPL's Mailroom to Mars and Beyond",
#  'The MarCO Mission Comes to an End',
#  "NASA's Mars 2020 Rover Tests Descent-Stage Separation",
#  "NASA's Mars 2020 Heads Into the Test Chamber",
#  'NASA Invites Students to Name Mars 2020 Rover',
#  "All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover",
#  "NASA's Mars 2020 Rover Closer to Getting Its Name",
#  'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020',
#  "NASA's Push to Save the Mars InSight Lander's Heat Probe",
#  "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#  "While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus",
#  'Mars Is Getting a New Robotic Meteorologist',
#  "Meet the People Behind NASA's Perseverance Rover",
#  "HiRISE Views NASA's InSight and Curiosity on Mars",
#  'Scientists Explore Outback as Testbed for Mars ',
#  "From JPL's Mailroom to Mars and Beyond",
#  'The MarCO Mission Comes to an End',
#  "NASA's Mars 2020 Rover Tests Descent-Stage Separation",
#  "NASA's Mars 2020 Heads Into the Test Chamber",
#  'NASA Invites Students to Name Mars 2020 Rover',
#  "All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover",
#  "NASA's Mars 2020 Rover Closer to Getting Its Name",
#  'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020',
#  "NASA's Push to Save the Mars InSight Lander's Heat Probe",
#  "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#  "While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus",
#  'Mars Is Getting a New Robotic Meteorologist',
#  "Meet the People Behind NASA's Perseverance Rover",
#  "HiRISE Views NASA's InSight and Curiosity on Mars",
#  'Scientists Explore Outback as Testbed for Mars ',
#  "From JPL's Mailroom to Mars and Beyond",
#  'The MarCO Mission Comes to an End',
#  "NASA's Mars 2020 Rover Tests Descent-Stage Separation",
#  "NASA's Mars 2020 Heads Into the Test Chamber",
#  'NASA Invites Students to Name Mars 2020 Rover',
#  "All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover",
#  "NASA's Mars 2020 Rover Closer to Getting Its Name",
#  'Two Rovers to Roll on Mars Again: Curiosity and Mars 2020',
#  "NASA's Push to Save the Mars InSight Lander's Heat Probe",
#  "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#  "While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus",
#  'Mars Is Getting a New Robotic Meteorologist',
#  "Meet the People Behind NASA's Perseverance Rover",
#  "HiRISE Views NASA's InSight and Curiosity on Mars"]

# %%
text_list
# Out:
# ["Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.",
#  'Bill Allen has thrived as the mechanical systems design lead for three Mars rover missions, but he got his start as a teenager sorting letters for the NASA center.',
#  'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.',
#  "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.",
#  'In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.',
#  "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.",
#  'SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.',
#  "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.",
#  'They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.',
#  "The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole.",
#  'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.',
#  "This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.",
#  "Sensors on NASA's Perseverance will help prepare for future human exploration by taking weather measurements and studying dust particles.",
#  "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. ",
#  'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.',
#  "Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.",
#  'Bill Allen has thrived as the mechanical systems design lead for three Mars rover missions, but he got his start as a teenager sorting letters for the NASA center.',
#  'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.',
#  "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.",
#  'In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.',
#  "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.",
#  'SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.',
#  "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.",
#  'They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.',
#  "The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole.",
#  'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.',
#  "This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.",
#  "Sensors on NASA's Perseverance will help prepare for future human exploration by taking weather measurements and studying dust particles.",
#  "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. ",
#  'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.',
#  "Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.",
#  'Bill Allen has thrived as the mechanical systems design lead for three Mars rover missions, but he got his start as a teenager sorting letters for the NASA center.',
#  'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.',
#  "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.",
#  'In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.',
#  "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.",
#  'SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.',
#  "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.",
#  'They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.',
#  "The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole.",
#  'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.',
#  "This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.",
#  "Sensors on NASA's Perseverance will help prepare for future human exploration by taking weather measurements and studying dust particles.",
#  "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. ",
#  'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.',
#  "Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.",
#  'Bill Allen has thrived as the mechanical systems design lead for three Mars rover missions, but he got his start as a teenager sorting letters for the NASA center.',
#  'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.',
#  "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.",
#  'In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.',
#  "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.",
#  'SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.',
#  "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.",
#  'They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.',
#  "The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole.",
#  'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.',
#  "This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.",
#  "Sensors on NASA's Perseverance will help prepare for future human exploration by taking weather measurements and studying dust particles.",
#  "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. ",
#  'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.',
#  "Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.",
#  'Bill Allen has thrived as the mechanical systems design lead for three Mars rover missions, but he got his start as a teenager sorting letters for the NASA center.',
#  'The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.',
#  "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.",
#  'In this time-lapse video taken at JPL, engineers move the Mars 2020 rover into a large vacuum chamber for testing in Mars-like environmental conditions.',
#  "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.",
#  'SuperCam is a rock-vaporizing instrument that will help scientists hunt for Mars fossils.',
#  "155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.",
#  'They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play.',
#  "The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the mole against the wall of its hole.",
#  'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.',
#  "This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.",
#  "Sensors on NASA's Perseverance will help prepare for future human exploration by taking weather measurements and studying dust particles.",
#  "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. ",
#  'New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.']

# %%
browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON

# %%
# Export data to MongoDB
